# %% [raw]
# 1)Load admission prediction dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading the data
data=pd.read_excel('Admission_prediction.xlsx')
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1.0      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2.0      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3.0        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4.0      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5.0      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495       496.0      332.0        108.0                5.0  4.5  4.0  9.02
# 496       497.0      337.0        117.0                5.0  5.0  5.0  9.87
# 497       498.0      330.0        120.0                5.0  4.5  5.0  9.56
# 498       499.0      312.0        103.0                4.0  4.0  5.0  8.43
# 499       500.0      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0         1.0             0.92
# ...

# %%
## Calling the dataframe and doing basic checks
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0         1.0      337.0        118.0                4.0  4.5  4.5  9.65
# 1         2.0      324.0        107.0                4.0  4.0  4.5  8.87
# 2         3.0        NaN        104.0                3.0  3.0  3.5  8.00
# 3         4.0      322.0        110.0                3.0  3.5  2.5  8.67
# 4         5.0      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0       1.0             0.92
# 1       1.0             0.76
# 2       1.0             0.72
# 3       1.0             0.80
# 4       0.0             0.65

# %%
data.head(10)   #Calling first 10 rows
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0         1.0      337.0        118.0                4.0  4.5  4.5  9.65
# 1         2.0      324.0        107.0                4.0  4.0  4.5  8.87
# 2         3.0        NaN        104.0                3.0  3.0  3.5  8.00
# 3         4.0      322.0        110.0                3.0  3.5  2.5  8.67
# 4         5.0      314.0        103.0                2.0  2.0  3.0  8.21
# 5         6.0      330.0        115.0                5.0  4.5  3.0  9.34
# 6         7.0      321.0        109.0                NaN  3.0  4.0  8.20
# 7         8.0      308.0        101.0                2.0  3.0  4.0  7.90
# 8         9.0      302.0        102.0                1.0  2.0  1.5  8.00
# 9        10.0      323.0        108.0                3.0  3.5  3.0  8.60
#
#    Research  Chance of Admit
# 0       1.0             0.92
# 1       1.0             0.76
# 2       1.0             0.72
# 3       1.0             0.80
# ...

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 495       496.0      332.0        108.0                5.0  4.5  4.0  9.02
# 496       497.0      337.0        117.0                5.0  5.0  5.0  9.87
# 497       498.0      330.0        120.0                5.0  4.5  5.0  9.56
# 498       499.0      312.0        103.0                4.0  4.0  5.0  8.43
# 499       500.0      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 495       1.0             0.87
# 496       1.0             0.96
# 497       1.0             0.93
# 498       0.0             0.73
# 499       0.0             0.84

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  485.000000   490.000000         485.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.121649    3.374000
# std    144.481833   11.274704     6.112899           1.146160    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# ...

# %% [raw]
# 1) GRE score has more spread than the others.
# 2) GRE score has more deviation as compared to others.

# %%
data.info()
#No missing values are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    float64
#  1   GRE Score          485 non-null    float64
#  2   TOEFL Score        490 non-null    float64
#  3   University Rating  485 non-null    float64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    float64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(9)
# memory usage: 35.3 KB

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
data.drop('Serial No.',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
data.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835273           0.638159  0.616434
# TOEFL Score         0.835273     1.000000           0.655072  0.647666
# University Rating   0.638159     0.655072           1.000000  0.723497
# SOP                 0.616434     0.647666           0.723497  1.000000
# LOR                 0.531996     0.541949           0.611437  0.663707
# CGPA                0.829391     0.810473           0.706012  0.712154
# Research            0.553755     0.469540           0.431253  0.408116
# Chance of Admit     0.810817     0.792369           0.690195  0.684137
#
#                         LOR      CGPA  Research  Chance of Admit
# GRE Score          0.531996  0.829391  0.553755         0.810817
# TOEFL Score        0.541949  0.810473  0.469540         0.792369
# University Rating  0.611437  0.706012  0.431253         0.690195
# SOP                0.663707  0.712154  0.408116         0.684137
# ...

# %% [raw]
# Task: 2)Perform EDA

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0      337.0        118.0                4.0  4.5  4.5  9.65       1.0
# 1      324.0        107.0                4.0  4.0  4.5  8.87       1.0
# 2        NaN        104.0                3.0  3.0  3.5  8.00       1.0
# 3      322.0        110.0                3.0  3.5  2.5  8.67       1.0
# 4      314.0        103.0                2.0  2.0  3.0  8.21       0.0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
##Univariate analysis
sns.histplot(x='CGPA',data=data)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Count'>

# %%
sns.displot(x='CGPA',data=data,kde=True)

# %%
sns.histplot(x='University Rating',data=data)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='Count'>

# %%
sns.displot(x='University Rating',data=data,kde=True)

# %%
sns.histplot(x='SOP',data=data)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='Count'>

# %%
sns.displot(x='SOP',data=data,kde=True)

# %%
sns.histplot(x='LOR',data=data)
# Out:
# <AxesSubplot:xlabel='LOR', ylabel='Count'>

# %%
sns.displot(x='LOR',data=data,kde=True)

# %%
data.head(1)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0         1.0      337.0        118.0                4.0  4.5  4.5  9.65
#
#    Research  Chance of Admit
# 0       1.0             0.92

# %%
## Bivariate Analysis
sns.relplot(x='CGPA',y='Chance of Admit',data=data)

# %%
sns.relplot(x='GRE Score',y='Chance of Admit',data=data)

# %%
sns.relplot(x='TOEFL Score',y='Chance of Admit',data=data)

# %%
data.head(1)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0         1.0      337.0        118.0                4.0  4.5  4.5  9.65
#
#    Research  Chance of Admit
# 0       1.0             0.92

# %%
sns.barplot(x='Research',y='Chance of Admit',data=data)
# Out:
# <AxesSubplot:xlabel='Research', ylabel='Chance of Admit'>

# %%
sns.barplot(x='SOP',y='Chance of Admit',data=data)
# Out:
# <AxesSubplot:xlabel='SOP', ylabel='Chance of Admit'>

# %%
sns.barplot(x='University Rating',y='Chance of Admit',data=data)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='Chance of Admit'>

# %%
sns.barplot(x='LOR',y='Chance of Admit',data=data)
# Out:
# <AxesSubplot:xlabel='LOR', ylabel='Chance of Admit'>

# %%
##Multivariate analysis
sns.pairplot(data)

# %%
data.head(1)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0      337.0        118.0                4.0  4.5  4.5  9.65       1.0
#
#    Chance of Admit
# 0             0.92

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.head(1)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0      337.0        118.0                4.0  4.5  4.5  9.65       1.0
#
#    Chance of Admit
# 0             0.92

# %%
##Checking the outliers
sns.boxplot(x='GRE Score',data=data)
# Out:
# <AxesSubplot:xlabel='GRE Score'>

# %%
sns.boxplot(x='TOEFL Score',data=data)
# Out:
# <AxesSubplot:xlabel='TOEFL Score'>

# %%
sns.boxplot(x='University Rating',data=data)
# Out:
# <AxesSubplot:xlabel='University Rating'>

# %%
sns.boxplot(x='SOP',data=data)
# Out:
# <AxesSubplot:xlabel='SOP'>

# %%
sns.boxplot(x='LOR',data=data)
# Outlier is present
# Out:
# <AxesSubplot:xlabel='LOR'>

# %%
sns.boxplot(x='CGPA',data=data)
# Out:
# <AxesSubplot:xlabel='CGPA'>

# %%
sns.boxplot(x='Chance of Admit',data=data)
## Outlier is present
# Out:
# <AxesSubplot:xlabel='Chance of Admit'>

# %%
data2=data.iloc[:,:9]
data2
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337.0        118.0                4.0  4.5  4.5  9.65       1.0
# 1        324.0        107.0                4.0  4.0  4.5  8.87       1.0
# 2          NaN        104.0                3.0  3.0  3.5  8.00       1.0
# 3        322.0        110.0                3.0  3.5  2.5  8.67       1.0
# 4        314.0        103.0                2.0  2.0  3.0  8.21       0.0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495      332.0        108.0                5.0  4.5  4.0  9.02       1.0
# 496      337.0        117.0                5.0  5.0  5.0  9.87       1.0
# 497      330.0        120.0                5.0  4.5  5.0  9.56       1.0
# 498      312.0        103.0                4.0  4.0  5.0  8.43       0.0
# 499      327.0        113.0                4.0  4.5  4.5  9.04       0.0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %%
data2.isnull().sum()
# Out:
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
data2.loc[data['GRE Score'].isnull()==True,'GRE Score']=np.median(data2['GRE Score'].dropna(axis=0))

# %%
data2.loc[data['TOEFL Score'].isnull()==True,'TOEFL Score']=np.median(data2['TOEFL Score'].dropna(axis=0))

# %%
data2.loc[data['University Rating'].isnull()==True,'University Rating']=np.median(data2['University Rating'].dropna(axis=0))

# %%
data2.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
data2[['GRE Score','TOEFL Score','University Rating','SOP','LOR','CGPA','Research','Chance of Admit']]=scale.fit_transform(data[['GRE Score','TOEFL Score','University Rating','SOP','LOR','CGPA','Research','Chance of Admit']])

# %% [raw]
# Task 3)Create an ML model to predict the percentage of getting admission in the university

# %% [markdown]
# ## Model Creation

# %%
#Step1: Independent and dependent variable creation
x=data2[['GRE Score','TOEFL Score','University Rating','SOP','LOR','CGPA','Research']]
y=data2['Chance of Admit']

# %%
# step2: Training and testing data creation
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
x_test
# Out:
#      GRE Score  TOEFL Score  University Rating    SOP    LOR      CGPA  \
# 66        0.74     0.785714               0.50  0.500  0.500  0.711538
# 152       0.62     0.714286               1.00  1.000  1.000  0.724359
# 123       0.36     0.571429               0.50  0.625  0.625  0.455128
# 285       0.82     0.857143               1.00  0.750  0.750  0.788462
# 70        0.54     0.928571               1.00  1.000  1.000  0.910256
# ..         ...          ...                ...    ...    ...       ...
# 13        0.34     0.607143               0.50  0.750  0.500  0.384615
# 166       0.24     0.357143               0.50  0.625  1.000  0.490385
# 275       0.64     0.642857               0.50  0.625  0.500  0.692308
# 92        0.16     0.214286               0.25  0.750  0.500  0.394231
# 274       0.50     0.285714               0.00  0.250  0.375  0.368590
#
#      Research
# 66        0.0
# 152       1.0
# 123       0.0
# 285       1.0
# 70        1.0
# ..        ...
# ...

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating    SOP    LOR      CGPA  \
# 303       0.66     0.535714               0.50  0.625  0.625  0.560897
# 202       1.00     1.000000               1.00  0.875  0.875  0.996795
# 349       0.46     0.321429               0.50  0.375  0.500  0.397436
# 272       0.08     0.107143               0.00  0.125  0.125  0.269231
# 192       0.64     0.785714               1.00  0.875  0.750  0.685897
# ..         ...          ...                ...    ...    ...       ...
# 385       0.90     0.892857               1.00  1.000  1.000  0.967949
# 197       0.40     0.500000               0.25  0.625  0.375  0.490385
# 439       0.44     0.464286               0.25  0.125  0.500  0.532051
# 174       0.62     0.678571               0.75  0.750  0.750  0.695513
# 122       0.40     0.500000               0.75  0.125  0.375  0.500000
#
#      Research
# 303       1.0
# 202       1.0
# 349       0.0
# 272       0.0
# 192       1.0
# ..        ...
# ...

# %%
y_train
# Out:
# 303    0.619048
# 202    1.000000
# 349    0.444444
# 272    0.238095
# 192    0.825397
#          ...
# 385    0.984127
# 197    0.619048
# 439    0.507937
# 174    0.841270
# 122    0.365079
# Name: Chance of Admit, Length: 400, dtype: float64

# %%
y_test
# Out:
# 66     0.428571
# 152    0.825397
# 123    0.428571
# 285    0.936508
# 70     0.952381
#          ...
# 13     0.444444
# 166    0.492063
# 275    0.698413
# 92     0.000000
# 274    0.380952
# Name: Chance of Admit, Length: 100, dtype: float64

# %%
##Step 3: Creating Model
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
y_predict
# Out:
# array([0.72399432, 0.80641953, 0.49839183, 0.86263616, 0.94453808,
#        0.67464124, 0.46999075, 0.68219133, 0.68879072, 0.78576749,
#        0.51048119, 0.39211645, 0.67572927, 0.61047481, 0.7357917 ,
#        0.49490455, 0.2470809 , 0.5738012 , 0.80233811, 0.46726176,
#        0.31740608, 0.58020298, 0.78715899, 0.6767841 , 0.38270116,
#        0.22701901, 0.34711409, 0.36754313, 0.96481579, 0.60701826,
#        0.99002232, 0.78068257, 0.82945851, 0.82670953, 0.78698437,
#        0.74542031, 0.39794122, 0.44213872, 0.52799624, 0.90863999,
#        0.63347012, 0.95235752, 0.8069927 , 0.76934067, 0.78027291,
#        0.4598188 , 0.82132861, 0.70942763, 0.64061472, 0.49638745,
#        0.70102406, 0.62324264, 0.48961212, 0.92659801, 0.41773445,
#        0.88088702, 0.81805396, 0.64772048, 0.35136095, 0.56717306,
#        0.49877417, 0.96817213, 0.91714919, 0.61507616, 0.58026902,
#        0.59306212, 0.9687979 , 0.87985003, 0.65158208, 1.011154  ,
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    float64
#  1   TOEFL Score        500 non-null    float64
#  2   University Rating  500 non-null    float64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    float64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(8)
# memory usage: 31.4 KB

# %%
from sklearn.svm import SVR
svregression = SVR() 
svregression.fit(x_train, y_train)
# Out:
# SVR()

# %%
##Step4: Model evaluation
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)
print('r2score of model: ',r2score)
# Out:
# r2score of model:  0.7688336456484537

# %%
x_test.shape
# Out:
# (100, 7)

# %%
adjusted_r2=1-(1-0.73)*(100-3)/(100-3-1)
adjusted_r2
# Out:
# 0.7271875

# %%
import math
print('mean squared error: ',mean_squared_error(y_test,y_predict))
##root mean squared error
print('Root mean squared error: ', math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# mean squared error:  0.010729846392095297
# Root mean squared error:  0.10358497184483517

# %%
print('mean absolute error of model: ',mean_absolute_error(y_test,y_predict))
# Out:
# mean absolute error of model:  0.07243852144795228

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\Documents\\02 MAY- CDS- ONLINE- WEEKDAY\\LINEAR REGRESSION'
